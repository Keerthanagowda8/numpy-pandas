# %%
import pandas as pd

# %%
ad=pd.read_csv("Attrition_dataset.csv")

# %%
ad.columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
# ...

# %%
ad
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %%
ad.head(15)
# Out:
#     EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0         1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1         1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2         1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3         1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4         1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5         1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6         1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7         1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8         1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9         1318  12/31/2015 0:00      1/3/1954        8/28/1989
# 10        1319  12/31/2006 0:00      1/3/1957        8/28/1989
# 11        1319  12/31/2007 0:00      1/3/1957        8/28/1989
# 12        1319  12/31/2008 0:00      1/3/1957        8/28/1989
# 13        1319  12/31/2009 0:00      1/3/1957        8/28/1989
# ...

# %%
ad.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %%
l=ad.columns[[1,2,3,4]]

# %%
for i in l:
    ad[i]=pd.to_datetime(ad[i])

# %% [markdown]
# ad["recorddate_key"]=pd.to_datetime(ad["recorddate_key"])
# ad.birthdate_key=pd.to_datetime(ad.birthdate_key)
# ad["orighiredate_key"]=pd.to_datetime(ad.orighiredate_key)
# ad["terminationdate_key"]=pd.to_datetime(ad.terminationdate_key)
# Instead of writing 4 lines we can use for loop

# %%
ad.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49648    False
# 49649    False
# 49650    False
# 49651    False
# 49652    False
# Length: 49653, dtype: bool

# %%
ad.EmployeeID.duplicated().all()
# Out:
# False

# %%
ad.EmployeeID=ad.EmployeeID.drop_duplicates(keep="last")

# %% [markdown]
# can keep 1st or last
# keep="first"
# keep="last"
# keep=None
# after removing dulipcate EmployeeID int is converted to null because int and null not together

# %%
ad=ad.dropna()

# %% [markdown]
# (axis=0,axis=1)
# 0=row
# 1=columns

# %%
ad.head(10)
# Out:
#     EmployeeID recorddate_key birthdate_key orighiredate_key  \
# 9       1318.0     2015-12-31    1954-01-03       1989-08-28
# 19      1319.0     2015-12-31    1957-01-03       1989-08-28
# 29      1320.0     2015-12-31    1955-01-02       1989-08-28
# 39      1321.0     2015-12-31    1959-01-02       1989-08-28
# 49      1322.0     2015-12-31    1958-01-09       1989-08-31
# 59      1323.0     2015-12-31    1962-01-09       1989-08-31
# 69      1325.0     2015-12-31    1964-01-13       1989-09-02
# 79      1328.0     2015-12-31    1956-01-17       1989-09-05
# 89      1329.0     2015-12-31    1967-01-23       1989-09-08
# 99      1330.0     2015-12-31    1967-01-25       1989-09-09
#
#    terminationdate_key  age  length_of_service  city_name   department_name  \
# 9           1900-01-01   61                 26  Vancouver         Executive
# 19          1900-01-01   58                 26  Vancouver         Executive
# ...

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6284 entries, 9 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           6284 non-null   float64
#  1   recorddate_key       6284 non-null   datetime64[ns]
#  2   birthdate_key        6284 non-null   datetime64[ns]
#  3   orighiredate_key     6284 non-null   datetime64[ns]
#  4   terminationdate_key  6284 non-null   datetime64[ns]
#  5   age                  6284 non-null   int64
#  6   length_of_service    6284 non-null   int64
#  7   city_name            6284 non-null   object
#  8   department_name      6284 non-null   object
#  9   job_title            6284 non-null   object
#  10  store_name           6284 non-null   int64
#  11  gender_short         6284 non-null   object
#  12  gender_full          6284 non-null   object
#  13  termreason_desc      6284 non-null   object
# ...

# %%
ad=ad.reset_index(drop=True)

# %%
ad.duplicated().any()
# Out:
# False

# %%
ad=ad.astype({"EmployeeID":int})

# %%
ad.store_name.unique()
# Out:
# array([35, 32, 18, 43, 29, 16, 26, 15,  8, 36, 38, 21, 44,  5, 25, 17, 28,
#         1, 30,  2, 22, 31, 41,  6, 46, 40, 33, 12,  3, 19, 42, 37,  9,  7,
#        13, 45, 39, 20, 11, 14, 34, 23, 24, 27, 10,  4], dtype=int64)

# %%
ad=ad.drop(columns=['store_name','gender_short'])

# %%
col_rename=['eid','record_date','dob','hire_date','term_date','age','experience','city',
   'dept','job','gender','term_reason','term_type','status_year','status','business_unit']

# %%
ad.columns=col_rename

# %%
ad.columns
# Out:
# Index(['eid', 'record_date', 'dob', 'hire_date', 'term_date', 'age',
#        'experience', 'city', 'dept', 'job', 'gender', 'term_reason',
#        'term_type', 'status_year', 'status', 'business_unit'],
#       dtype='object')

# %%
ad.agg({'age':[min,max],'experience':[min,max]})
# Out:
# C:\Users\Keerthana\AppData\Local\Temp\ipykernel_11616\2239457428.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   ad.agg({'age':[min,max],'experience':[min,max]})
# C:\Users\Keerthana\AppData\Local\Temp\ipykernel_11616\2239457428.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ad.agg({'age':[min,max],'experience':[min,max]})
#      age  experience
# min   19           0
# max   65          26

# %%
ad["age_category"]=pd.cut(ad['age'],bins=[18,30,59,65],labels=['Teen','Adult','Senior'],right=True,include_lowest=True)
ad["exp_level"]=pd.cut(ad['experience'],bins=[0,3,15,26],labels=['Fresher','Intermidiate','Expert'],right=True,include_lowest=True)

# %%
# ad.business_unit=ad.business_unit.str.title()
# ad.status=ad.status.str.title()
for i in ['status','business_unit']:
    ad[i]=ad[i].str.title()

# %%
ad.loc[ad['status']=='Active']
# Out:
#        eid record_date        dob  hire_date  term_date  age  experience  \
# 0     1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61          26
# 1     1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58          26
# 2     1320  2015-12-31 1955-01-02 1989-08-28 1900-01-01   60          26
# 3     1321  2015-12-31 1959-01-02 1989-08-28 1900-01-01   56          26
# 4     1322  2015-12-31 1958-01-09 1989-08-31 1900-01-01   57          26
# ...    ...         ...        ...        ...        ...  ...         ...
# 4794  8332  2015-12-31 1994-12-20 2013-12-05 1900-01-01   21           2
# 4795  8333  2015-12-31 1994-12-19 2013-12-05 1900-01-01   21           2
# 4796  8334  2015-12-31 1994-12-27 2013-12-09 1900-01-01   21           2
# 4797  8335  2015-12-31 1994-12-28 2013-12-10 1900-01-01   21           2
# 4798  8336  2015-12-31 1994-12-31 2013-12-11 1900-01-01   21           2
#
#                 city              dept                 job  gender  \
# ...

# %%
ad.loc[ad['status']=="Terminated"]
# Out:
#        eid record_date        dob  hire_date  term_date  age  experience  \
# 4799  1338  2009-02-01 1949-02-16 1989-09-20 2009-02-16   60          19
# 4800  1339  2014-02-01 1949-02-19 1989-09-22 2014-02-19   65          24
# 4801  1340  2009-02-01 1949-02-19 1989-09-22 2009-02-19   60          19
# 4802  1341  2009-02-01 1949-02-21 1989-09-23 2009-02-21   60          19
# 4803  1343  2014-02-01 1949-02-24 1989-09-25 2014-02-24   65          24
# ...    ...         ...        ...        ...        ...  ...         ...
# 6279  8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280  8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281  8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282  8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283  8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              city              dept                        job  gender  \
# ...

# %% [markdown]
# get the termdate of active employees

# %%
active_term=ad.loc[ad['status']=='Active','term_date']

# %% [markdown]
# get the record date of active emp

# %%
active_record=ad.loc[ad['status']=='Active','record_date']

# %%
ad.loc[ad['status']=='Active','term_date']=active_record

# %%
ad
# Out:
#        eid record_date        dob  hire_date  term_date  age  experience  \
# 0     1318  2015-12-31 1954-01-03 1989-08-28 2015-12-31   61          26
# 1     1319  2015-12-31 1957-01-03 1989-08-28 2015-12-31   58          26
# 2     1320  2015-12-31 1955-01-02 1989-08-28 2015-12-31   60          26
# 3     1321  2015-12-31 1959-01-02 1989-08-28 2015-12-31   56          26
# 4     1322  2015-12-31 1958-01-09 1989-08-31 2015-12-31   57          26
# ...    ...         ...        ...        ...        ...  ...         ...
# 6279  8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280  8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281  8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282  8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283  8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              city              dept                 job  gender  \
# ...

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6284 entries, 0 to 6283
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   eid            6284 non-null   int32
#  1   record_date    6284 non-null   datetime64[ns]
#  2   dob            6284 non-null   datetime64[ns]
#  3   hire_date      6284 non-null   datetime64[ns]
#  4   term_date      6284 non-null   datetime64[ns]
#  5   age            6284 non-null   int64
#  6   experience     6284 non-null   int64
#  7   city           6284 non-null   object
#  8   dept           6284 non-null   object
#  9   job            6284 non-null   object
#  10  gender         6284 non-null   object
#  11  term_reason    6284 non-null   object
#  12  term_type      6284 non-null   object
#  13  status_year    6284 non-null   int64
#  14  status         6284 non-null   object
#  15  business_unit  6284 non-null   object
#  16  age_category   6284 non-null   category
# ...
