# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")

# %% [markdown]
# read_excel()
# read_json()

# %%
df.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# missing data is present in columns age,fare,cabin,embarked

# %%
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
df.head(10)
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
# 6       1                Andrews, Miss. Kornelia Theodosia  female  63.0000
# 7       1                           Andrews, Mr. Thomas Jr    male  39.0000
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0000
# 9       1                          Artagaveytia, Mr. Ramon    male  71.0000
#
#    sibsp  parch    ticket      fare    cabin embarked  survived
# 0      0      0     24160  211.3375       B5        S         1
# ...

# %%
df.tail()
# Out:
#       pclass                       name     sex   age  sibsp  parch  ticket  \
# 1304       3       Zabour, Miss. Hileni  female  14.5      1      0    2665
# 1305       3      Zabour, Miss. Thamine  female   NaN      1      0    2665
# 1306       3  Zakarian, Mr. Mapriededer    male  26.5      0      0    2656
# 1307       3        Zakarian, Mr. Ortin    male  27.0      0      0    2670
# 1308       3         Zimmerman, Mr. Leo    male  29.0      0      0  315082
#
#          fare cabin embarked  survived
# 1304  14.4542   NaN        C         0
# 1305  14.4542   NaN        C         0
# 1306   7.2250   NaN        C         0
# 1307   7.2250   NaN        C         0
# 1308   7.8750   NaN        S         0

# %%
df["embarked"].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %% [markdown]
# used to find the unique values and nan refers to null

# %%
df["pclass"].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
age_mean=df["age"].mean()
age_mean
# Out:
# 29.8811345124283

# %%
fare_mean=df["fare"].mean()
fare_mean
# Out:
# 33.29547928134557

# %% [markdown]
# fill null value = fillna(variable or number )

# %%
df["fare"]=df["fare"].fillna(fare_mean)

# %%
df["age"]=df["age"].fillna(age_mean)

# %%
name_mode=df["name"].mode()[0]
name_mode
# Out:
# 'Connolly, Miss. Kate'

# %%
embarked=df["embarked"].mode()[0]
embarked
# Out:
# 'S'

# %%
df["embarked"]=df["embarked"].fillna(embarked)

# %% [markdown]
# mode is used to get most repeated values
# it can return more than values
# so use index[0] to get one value
#
# name_mode=df["name"].mode()
# name_mode
# op:
# 0    Connolly, Miss. Kate
# 1        Kelly, Mr. James
# Name: name, dtype: object
#
# name_mode=df["name"].mode()[0]
# name_mode
# op:
# 'Connolly, Miss. Kate'

# %%
df=df.drop(columns=["cabin"])

# %% [markdown]
# drop(index=[],columns=[])
# index for row number
# columns for column name

# %%
df=df.rename(columns={"sex":"gender"})

# %% [markdown]
# both drop and rename works on two things column and index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   gender    1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   embarked  1309 non-null   object
#  9   survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 102.4+ KB

# %% [markdown]
# data transformation, data manupalation, Feature Engineering
# column- (feature,property,variable in table,attribute)

# %%
df["family_count"]=df["sibsp"]+df["parch"]

# %% [markdown]
# To create new column called family count from the sibsp and parch

# %%
df
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket      fare embarked  survived  \
# ...

# %%
df=df.drop(columns=['sibsp','parch'])

# %% [markdown]
# to drop multiple columns

# %%
df['age']=df['age'].round(1)
df['fare']=df['fare'].round(1)

# %% [markdown]
# round number to decimal number

# %%
df
# Out:
#       pclass                                             name  gender   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  female  29.0
# 1          1                   Allison, Master. Hudson Trevor    male   0.9
# 2          1                     Allison, Miss. Helen Loraine  female   2.0
# 3          1             Allison, Mr. Hudson Joshua Creighton    male  30.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# ...      ...                                              ...     ...   ...
# 1304       3                             Zabour, Miss. Hileni  female  14.5
# 1305       3                            Zabour, Miss. Thamine  female  29.9
# 1306       3                        Zakarian, Mr. Mapriededer    male  26.5
# 1307       3                              Zakarian, Mr. Ortin    male  27.0
# 1308       3                               Zimmerman, Mr. Leo    male  29.0
#
#       ticket   fare embarked  survived  family_count
# ...

# %%
df['gender']=df['gender'].str.title()

# %% [markdown]
# title case : column are in object datatype so pandas can not use string built-in functions.so use str method to fetch every data from column and convert it into string no need of looping.
# str: it is an attribute which helpus to apply str_built_in method

# %% [markdown]
# df['column_name'].str.upper()
# df['column_name'].str.lower()

# %%
df['embarked']=df.embarked.replace({'S':"Southampton",'C':"Cherbourg",'Q':"Queenstown"})

# %% [markdown]
# df.replace({}) -> replace for all columns
# df["column"].replace({})

# %% [markdown]
# replacing old value to new value.use replace and arguments should be given in the form of dict

# %%
df[["lname","fname"]]=df['name'].str.split(',',expand=True)

# %%
df[["courtesy_title","fname"]]=df['fname'].str.split('.',n=1,expand=True)

# %%
df=df.drop(columns=['name'])

# %%
for col in['courtesy_title','fname','lname']:
    df[col]=df[col].str.strip()

# %% [markdown]
# strip is used to remove white spaces . insteadd od doing for columns seperately like this df['fname']=df['fname'].str.strip() we can use for loop

# %%
ticket_cnt=df['ticket'].value_counts()

# %%
ticket_cnt=ticket_cnt.reset_index()

# %%
ticket_cnt
# Out:
#        ticket  count
# 0    CA. 2343     11
# 1        1601      8
# 2     CA 2144      8
# 3    PC 17608      7
# 4      347077      7
# ..        ...    ...
# 924    373450      1
# 925      2223      1
# 926    350046      1
# 927   3101281      1
# 928    315082      1
#
# [929 rows x 2 columns]

# %% [markdown]
# value count is used to find how many times value is present
# When ever we use this group by aggregate function
# so that grouped data is called index
# and aggregate fun is called values
# return type is series

# %%
df=pd.merge(df,ticket_cnt,'inner',on='ticket')

# %% [markdown]
# joining two tables pd.merge(left_table,right_table,how="inner",on="ticket")
# cross,left,right,outer

# %%
df=df.rename(columns={'count':'psg cnt'})

# %%
l=['ticket','courtesy_title','fname','lname','gender','age','embarked','family_count','psg cnt','pclass','fare','survived']

# %%
df=df[l]

# %%
df=df.rename(columns={'fare':"total fare"})

# %%
df['indivdual fare']=df['total fare']/df['psg cnt']
df
# Out:
#       ticket courtesy_title                              fname      lname  \
# 0      24160           Miss                   Elisabeth Walton      Allen
# 1     113781         Master                      Hudson Trevor    Allison
# 2     113781           Miss                      Helen Loraine    Allison
# 3     113781             Mr            Hudson Joshua Creighton    Allison
# 4     113781            Mrs  Hudson J C (Bessie Waldo Daniels)    Allison
# ...      ...            ...                                ...        ...
# 1304    2665           Miss                             Hileni     Zabour
# 1305    2665           Miss                            Thamine     Zabour
# 1306    2656             Mr                        Mapriededer   Zakarian
# 1307    2670             Mr                              Ortin   Zakarian
# 1308  315082             Mr                                Leo  Zimmerman
#
#       gender   age     embarked  family_count  psg cnt  pclass  total fare  \
# ...

# %%
df['fname']='Emil'
df
# Out:
#       ticket courtesy_title fname      lname  gender   age     embarked  \
# 0      24160           Miss  Emil      Allen  Female  29.0  Southampton
# 1     113781         Master  Emil    Allison    Male   0.9  Southampton
# 2     113781           Miss  Emil    Allison  Female   2.0  Southampton
# 3     113781             Mr  Emil    Allison    Male  30.0  Southampton
# 4     113781            Mrs  Emil    Allison  Female  25.0  Southampton
# ...      ...            ...   ...        ...     ...   ...          ...
# 1304    2665           Miss  Emil     Zabour  Female  14.5    Cherbourg
# 1305    2665           Miss  Emil     Zabour  Female  29.9    Cherbourg
# 1306    2656             Mr  Emil   Zakarian    Male  26.5    Cherbourg
# 1307    2670             Mr  Emil   Zakarian    Male  27.0    Cherbourg
# 1308  315082             Mr  Emil  Zimmerman    Male  29.0  Southampton
#
#       family_count  psg cnt  pclass  total fare  survived  indivdual fare
# ...

# %%
df.loc[df['fname']=='Emil']
# Out:
#       ticket courtesy_title fname      lname  gender   age     embarked  \
# 0      24160           Miss  Emil      Allen  Female  29.0  Southampton
# 1     113781         Master  Emil    Allison    Male   0.9  Southampton
# 2     113781           Miss  Emil    Allison  Female   2.0  Southampton
# 3     113781             Mr  Emil    Allison    Male  30.0  Southampton
# 4     113781            Mrs  Emil    Allison  Female  25.0  Southampton
# ...      ...            ...   ...        ...     ...   ...          ...
# 1304    2665           Miss  Emil     Zabour  Female  14.5    Cherbourg
# 1305    2665           Miss  Emil     Zabour  Female  29.9    Cherbourg
# 1306    2656             Mr  Emil   Zakarian    Male  26.5    Cherbourg
# 1307    2670             Mr  Emil   Zakarian    Male  27.0    Cherbourg
# 1308  315082             Mr  Emil  Zimmerman    Male  29.0  Southampton
#
#       family_count  psg cnt  pclass  total fare  survived  indivdual fare
# ...

# %%
df.loc[(df['fname']=='Emil')&(df['age']==29.0)]
# Out:
#                  ticket courtesy_title fname              lname  gender   age  \
# 0                 24160           Miss  Emil              Allen  Female  29.0
# 24             PC 17483           Miss  Emil               Bird  Female  29.0
# 189              113501             Mr  Emil               Long    Male  29.0
# 226              113776             Mr  Emil              Pears    Male  29.0
# 369         SC/AH 29037            Mrs  Emil            Chapman  Female  29.0
# 372                2003             Mr  Emil             Clarke    Male  29.0
# 374         W./C. 14263             Mr  Emil          Coleridge    Male  29.0
# 391       SC/PARIS 2167             Mr  Emil          del Carlo    Male  29.0
# 407                2926            Mrs  Emil         Faunthorpe  Female  29.0
# 452               26707            Mrs  Emil               Hold  Female  29.0
# 521          C.A. 29395            Mrs  Emil                Nye  Female  29.0
# ...

# %%
df.loc[(df['ticket']=='343276') | (df['ticket']=='110413')]
df.loc[df['ticket'].isin(['343276','110413'])]
# Out:
#      ticket courtesy_title fname       lname  gender   age     embarked  \
# 289  110413           Miss  Emil     Taussig  Female  18.0  Southampton
# 290  110413             Mr  Emil     Taussig    Male  52.0  Southampton
# 291  110413            Mrs  Emil     Taussig  Female  39.0  Southampton
# 715  343276             Mr  Emil  Christmann    Male  29.0  Southampton
#
#      family_count  psg cnt  pclass  total fare  survived  indivdual fare
# 289             2        3       1        79.6         1       26.533333
# 290             2        3       1        79.6         0       26.533333
# 291             2        3       1        79.6         1       26.533333
# 715             0        1       3         8.0         0        8.000000

# %%
df.agg({'total fare':['count','max','min','sum','mean']})
# Out:
#          total fare
# count   1309.000000
# max      512.300000
# min        0.000000
# sum    43586.700000
# mean      33.297708

# %%
df.agg({'total fare':['mean','min'],'age':['min'],'survived':['mean']})
# Out:
#       total fare  age  survived
# mean   33.297708  NaN  0.381971
# min     0.000000  0.2       NaN

# %%
crew_members=df.loc[df['total fare']==0].reset_index(drop=True)

# %%
crew_members
# Out:
#     ticket courtesy_title fname       lname gender   age     embarked  \
# 0   112050             Mr  Emil     Andrews   Male  39.0  Southampton
# 1   112051             Mr  Emil    Chisholm   Male  29.9  Southampton
# 2   112058             Mr  Emil         Fry   Male  29.9  Southampton
# 3   112059             Mr  Emil    Harrison   Male  40.0  Southampton
# 4   112058             Mr  Emil       Ismay   Male  49.0  Southampton
# 5   112052             Mr  Emil        Parr   Male  29.9  Southampton
# 6    19972       Jonkheer  Emil    Reuchlin   Male  38.0  Southampton
# 7   239853             Mr  Emil    Campbell   Male  29.9  Southampton
# 8   239853             Mr  Emil  Cunningham   Male  29.9  Southampton
# 9   239854             Mr  Emil       Frost   Male  29.9  Southampton
# 10  239855             Mr  Emil      Knight   Male  29.9  Southampton
# 11  239853             Mr  Emil      Parkes   Male  29.9  Southampton
# ...

# %%
df=df.loc[df['total fare']!=0].reset_index(drop=True)

# %%
df.loc[df['total fare']==0].shape
# Out:
# (0, 13)

# %%
df=df.sort_values(by='ticket').reset_index(drop=True)
df
# Out:
#            ticket courtesy_title fname    lname  gender   age     embarked  \
# 0          110152           Miss  Emil   Maioni  Female  16.0  Southampton
# 1          110152           Miss  Emil   Cherry  Female  30.0  Southampton
# 2          110152   the Countess  Emil   Rothes  Female  33.0  Southampton
# 3          110413             Mr  Emil  Taussig    Male  52.0  Southampton
# 4          110413           Miss  Emil  Taussig  Female  18.0  Southampton
# ...           ...            ...   ...      ...     ...   ...          ...
# 1287  W.E.P. 5734             Mr  Emil  Chaffee    Male  46.0  Southampton
# 1288  W.E.P. 5734            Mrs  Emil  Chaffee  Female  47.0  Southampton
# 1289    W/C 14208             Mr  Emil   Harris    Male  30.0  Southampton
# 1290    WE/P 5735           Capt  Emil   Crosby    Male  70.0  Southampton
# 1291    WE/P 5735           Miss  Emil   Crosby  Female  36.0  Southampton
#
# ...

# %%
df.loc[df['total fare']==0].shape
df
# Out:
#            ticket courtesy_title fname    lname  gender   age     embarked  \
# 0          110152           Miss  Emil   Maioni  Female  16.0  Southampton
# 1          110152           Miss  Emil   Cherry  Female  30.0  Southampton
# 2          110152   the Countess  Emil   Rothes  Female  33.0  Southampton
# 3          110413             Mr  Emil  Taussig    Male  52.0  Southampton
# 4          110413           Miss  Emil  Taussig  Female  18.0  Southampton
# ...           ...            ...   ...      ...     ...   ...          ...
# 1287  W.E.P. 5734             Mr  Emil  Chaffee    Male  46.0  Southampton
# 1288  W.E.P. 5734            Mrs  Emil  Chaffee  Female  47.0  Southampton
# 1289    W/C 14208             Mr  Emil   Harris    Male  30.0  Southampton
# 1290    WE/P 5735           Capt  Emil   Crosby    Male  70.0  Southampton
# 1291    WE/P 5735           Miss  Emil   Crosby  Female  36.0  Southampton
#
# ...

# %%
df.agg({'total fare':['sum'],'age':['mean']})
# Out:
#       total fare        age
# sum      43586.7        NaN
# mean         NaN  29.841563

# %%
g=df.groupby('gender')
g

# %% [markdown]
# df.groupby('gender') : <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000016274E6F5F0> if we use group by it

# %%
g.agg({'total fare':['sum'],'age':['mean']})
# Out:
#        total fare        age
#               sum       mean
# gender
# Female    21531.2  28.890343
# Male      22055.5  30.378208

# %%
g.agg({'psg cnt':['count']})
# Out:
#        psg cnt
#          count
# gender
# Female     466
# Male       826

# %%
df.value_counts("gender")
# Out:
# gender
# Male      826
# Female    466
# Name: count, dtype: int64

# %%
df["age category"]=pd.cut(df['age'],bins=[0,2,15,30,59,100],labels=['infant','child','teen','adult','senior'],right=True,include_lowest=True)

# %%
df
# Out:
#            ticket courtesy_title fname    lname  gender   age     embarked  \
# 0          110152           Miss  Emil   Maioni  Female  16.0  Southampton
# 1          110152           Miss  Emil   Cherry  Female  30.0  Southampton
# 2          110152   the Countess  Emil   Rothes  Female  33.0  Southampton
# 3          110413             Mr  Emil  Taussig    Male  52.0  Southampton
# 4          110413           Miss  Emil  Taussig  Female  18.0  Southampton
# ...           ...            ...   ...      ...     ...   ...          ...
# 1287  W.E.P. 5734             Mr  Emil  Chaffee    Male  46.0  Southampton
# 1288  W.E.P. 5734            Mrs  Emil  Chaffee  Female  47.0  Southampton
# 1289    W/C 14208             Mr  Emil   Harris    Male  30.0  Southampton
# 1290    WE/P 5735           Capt  Emil   Crosby    Male  70.0  Southampton
# 1291    WE/P 5735           Miss  Emil   Crosby  Female  36.0  Southampton
#
# ...

# %% [markdown]
# for age greater than 100 then cut gives null to them
# include_lowest= is used to include 0 while assiging
# right =true is used to do range set 0-2 ,2-15,15-30 for this 2 is set

# %%
l=['ticket','courtesy_title','fname','lname','gender','age','age category','embarked','family_count','psg cnt','comp_type','pclass','total fare','indivdual fare','survived']

# %%
def comp_type(row):
    if(row['psg cnt'])==1:
        if(row['family_count']==0):
            return "solo"
    elif(row['psg cnt']>1):
        if row['family_count']>0 :
            return "family"
        elif row['family_count']==0:
            return "friends"
df['comp_type']=df.apply(comp_type,axis=1)

# %%
l=['ticket','courtesy_title','fname','lname','gender','age','age category','embarked','family_count','psg cnt','comp_type','pclass','total fare','indivdual fare','survived']

# %% [markdown]
# axis=1 , all columns of 1st row then 2nd row ,.....
# axis=0 , all row of 1st col, then 2nd col,......

# %%
df[l]
# Out:
#            ticket courtesy_title fname    lname  gender   age age category  \
# 0          110152           Miss  Emil   Maioni  Female  16.0         teen
# 1          110152           Miss  Emil   Cherry  Female  30.0         teen
# 2          110152   the Countess  Emil   Rothes  Female  33.0        adult
# 3          110413             Mr  Emil  Taussig    Male  52.0        adult
# 4          110413           Miss  Emil  Taussig  Female  18.0         teen
# ...           ...            ...   ...      ...     ...   ...          ...
# 1287  W.E.P. 5734             Mr  Emil  Chaffee    Male  46.0        adult
# 1288  W.E.P. 5734            Mrs  Emil  Chaffee  Female  47.0        adult
# 1289    W/C 14208             Mr  Emil   Harris    Male  30.0         teen
# 1290    WE/P 5735           Capt  Emil   Crosby    Male  70.0       senior
# 1291    WE/P 5735           Miss  Emil   Crosby  Female  36.0        adult
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292 entries, 0 to 1291
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ticket          1292 non-null   object
#  1   courtesy_title  1292 non-null   object
#  2   fname           1292 non-null   object
#  3   lname           1292 non-null   object
#  4   gender          1292 non-null   object
#  5   age             1292 non-null   float64
#  6   embarked        1292 non-null   object
#  7   family_count    1292 non-null   int64
#  8   psg cnt         1292 non-null   int64
#  9   pclass          1292 non-null   int64
#  10  total fare      1292 non-null   float64
#  11  survived        1292 non-null   int64
#  12  indivdual fare  1292 non-null   float64
#  13  age category    1292 non-null   category
#  14  comp_type       1242 non-null   object
# dtypes: category(1), float64(3), int64(4), object(7)
# memory usage: 142.9+ KB

# %%
df.describe()
# Out:
#                age  family_count      psg cnt       pclass   total fare  \
# count  1292.000000   1292.000000  1292.000000  1292.000000  1292.000000
# mean     29.841563      0.895511     2.100619     2.301084    33.735836
# std      12.932872      1.590759     1.785760     0.836743    51.936779
# min       0.200000      0.000000     1.000000     1.000000     3.200000
# 25%      22.000000      0.000000     1.000000     2.000000     7.900000
# 50%      29.900000      0.000000     1.000000     3.000000    14.500000
# 75%      35.000000      1.000000     3.000000     3.000000    31.400000
# max      80.000000     10.000000    11.000000     3.000000   512.300000
#
#           survived  indivdual fare
# count  1292.000000     1292.000000
# mean      0.385449       14.966873
# std       0.486890       13.542962
# min       0.000000        3.200000
# 25%       0.000000        7.666667
# 50%       0.000000        8.083333
# 75%       1.000000       15.012500
# ...
